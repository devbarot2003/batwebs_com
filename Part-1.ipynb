# %%
import pandas as pd

# %%
# read_csv method helps to read csv file

df = pd.read_csv("Iris.csv")

# %%
# displaying the csv data

df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#head method displays first five methods of a csv file

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#tail method displays data from the bottom of the csv file, according to the number given

df.tail(n=6)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#describe method displays the count, mean, std, minimum and maximum value, quartiles of numeric column

df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#percentiles in 20%, 50% and 70% 's quartile, instead of 25, 50 and 75%

df.describe(percentiles = [0.3, 0.5, 0.7])
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 30%     45.700000       5.270000      2.800000       1.700000      0.400000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 70%    105.300000       6.300000      3.200000       5.000000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#transpose of the describe method, which means rows label will get replaced by columns label and columns label by rows label

df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
#info method shows data types, missing values, memory usage, range or size of the DataFrame.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#shape method displays no. of rows and columns

df.shape
# Out:
# (150, 6)

# %%
#returns columns name in the form of index object

df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#reuturns coumns in the form of list

list(df.columns)
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
#with the use of loc method we can set the value of that particular locations to none or any value that the user wants

df1 = df.copy()
df1.loc[1:4, 'PetalLengthCm'] = None
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            NaN           0.2  Iris-setosa
# 2   3            4.7           3.2            NaN           0.2  Iris-setosa
# 3   4            4.6           3.1            NaN           0.2  Iris-setosa
# 4   5            5.0           3.6            NaN           0.2  Iris-setosa

# %%
#You can check whether each element in a DataFrame is missing using the .isnull() method.

df1.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    4
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Isolating column using pandas series. (1-D)

df ['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
#Isolating columns using pandas series. (2-D)

df[['Id','Species']]
# Out:
#       Id         Species
# 0      1     Iris-setosa
# 1      2     Iris-setosa
# 2      3     Iris-setosa
# 3      4     Iris-setosa
# 4      5     Iris-setosa
# ..   ...             ...
# 145  146  Iris-virginica
# 146  147  Iris-virginica
# 147  148  Iris-virginica
# 148  149  Iris-virginica
# 149  150  Iris-virginica
#
# [150 rows x 2 columns]

# %%
#1 represents the row index (label)

df1.loc[100:110]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica
# 105  Iris-virginica
# ...

# %%
#1 in .iloc[] is the row position (first row)

df1.iloc[100:110]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica
# 105  Iris-virginica
# 106  Iris-virginica
# 107  Iris-virginica
# 108  Iris-virginica
# ...

# %%
df1.loc[[100,125,149]]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 125  126            7.2           3.2            6.0           1.8
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 100  Iris-virginica
# 125  Iris-virginica
# 149  Iris-virginica

# %%
df1.loc[[100,110], ['Id', 'Species']]
# Out:
#       Id         Species
# 100  101  Iris-virginica
# 110  111  Iris-virginica

# %%
#dropping the rows where the data includes null value

df2 = df1.copy()
df2 = df1.dropna()
df2.shape
# Out:
# (146, 6)

# %%
#dropping the column which contain null values
df2 = df1.copy()
df2.dropna(inplace=True, axis=1)
df2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalWidthCm      Species
# 0   1            5.1           3.5           0.2  Iris-setosa
# 1   2            4.9           3.0           0.2  Iris-setosa
# 2   3            4.7           3.2           0.2  Iris-setosa
# 3   4            4.6           3.1           0.2  Iris-setosa
# 4   5            5.0           3.6           0.2  Iris-setosa

# %%
#
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            NaN           0.2  Iris-setosa
# 2   3            4.7           3.2            NaN           0.2  Iris-setosa
# 3   4            4.6           3.1            NaN           0.2  Iris-setosa
# 4   5            5.0           3.6            NaN           0.2  Iris-setosa
